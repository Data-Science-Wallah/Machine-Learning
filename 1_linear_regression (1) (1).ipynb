# %% [markdown]
# <h2 style="color:green" align="center">Machine Learning With Python: Linear Regression With One Variable</h2>

# %% [markdown]
# <h3 style="color:purple">Sample problem of predicting home price in monroe, new jersey (USA)</h3>

# %% [markdown]
# ![60968model1.jpg](data:image/jpeg;base64,...![homepricetable.JPG](data:image/jpeg;base64,...))

# %% [markdown]
# Linear Regression:
# Linear regression is a statistical method used to model the relationship between a dependent variable and one or more independent variables by fitting a linear equation to the observed data. In simple terms, it helps us understand how the value of the dependent variable changes with the change in one or more independent variables.
#
# Equation:
# For a simple linear regression with one independent variable, the equation is given by:
#
#
# y=mx+b
#
# where:
#
#
# y is the dependent variable (per capita income in this case),
#
#
# x is the independent variable (year),
#
#
# m is the slope of the line,
#
#
# b is the y-intercept.

# %% [markdown]
# **Problem Statement**: Given above data build a machine learning model that can predict home prices based on square feet area

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price,color="red")

# %%
new_df=df.drop("price",axis="columns")
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# creating obj for LR
reg=linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %% [markdown]
# # 1- predict home price for 3300 sqft

# %%
reg.predict([[3300]])    # y=reg.predict([[3300]])    x=3300
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_                    #m
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
y=reg.coef_*3300 +reg.intercept_
y
# Out:
# array([628715.75342466])

# %% [markdown]
# # 1- predict home price for 500 sqft

# %%
reg.predict([[500]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([248510.2739726])

# %%
area_df=pd.read_csv("areas.csv")
area_df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(area_df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_df["prices"]=p
area_df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv("pred.csv")

# %% [markdown]
# <h3>Exercise</h3>

# %% [markdown]
# <p >Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020</p>

# %% [markdown]
# <h3>Answer</h3>

# %% [markdown]
# 41288.69409442
